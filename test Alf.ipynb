# %%
""" The text we will use is an Italian news article about vaccines """
file = 'sample_article.txt'

with open(file, 'r') as fr:
    text = fr.read()
    

""" Text we will use as baseline will be a similar one"""
file = 'another_text_[baseline].txt'

with open(file, 'r') as fr:
    baseline_text = fr.read()
    
text += ' prevalere prevale prevarrà prevalente'
print(text)

# %%
from emotionslib import EmoScores

emos = EmoScores(language = 'italian')

""" 1.1 Get emotion counts """
emo_counts = emos.emotions(text)

print("1.1 Emotion counts from text: ")
print(emo_counts)
print()


""" 1.2 Get valence """
valence = emos.valence(text)

print("1.2 Valence in text: ")
print(valence)
print()


""" 2. Get zscores against default baseline """
zscores = emos.zscores(text)

print("2. Z-scores from text (no baseline provided, fallback to default baseline):")
print(zscores)
print()


""" 3.1 Get zscores against custom baseline """
zscores = emos.zscores(text, baseline = baseline_text)

print("3.1 Z-scores from text against custom baseline:")
print(zscores)
print()


""" 3.2 Set a permanent baseline (works best for multiple files) """
# baseline same as before
emos.set_baseline(baseline_text)
zscores = emos.zscores(text)

print("3.2 Loaded a baseline and then z-scores from text (now the baseline is permanent!):")
print(zscores)
print()

""" 4.1 Get a formamentis network and print emotion counts """
edges, vertex = emos.formamentis_network(text)
emo_counts = emos.emotions(edges)

print("4.1 Get a Formamentis network from text and then emotion counts: ")
print(emo_counts)
print()


""" 4.2 Draw the formamentis of a sentence """

sentence = """E' allora arrivato il tempo di fare un’operazione verità e di farla finita con le manfrine, altrimenti avremo modo di tutelarci 
in tutte le sedi e arriveremo a chiedere l’invalidazione del piano di distribuzione approvato 20 giorni fa."""
valence = emos.valence(sentence)
edges, vertex = emos.formamentis_network(sentence, with_type = True)

emos.draw_formamentis(edges)

print("4.2 Get valence of sentence (drawing below):")
print(valence)
print()

""" 5. Get a formamentis network and print z-scores """
# baseline same as before
edges, vertex = emos.formamentis_network(text)
zscores = emos.zscores(edges)

print("5. Get a Formamentis network from text and then z-scores against the loaded baseline:")
print(zscores)
print()


""" 6. Get a formamentis network about "vaccino" and print emotion counts """
edges, vertex = emos.formamentis_network(text, target_word = "vaccino")
emo_counts = emos.emotions(edges)

print("6. Get a Formamentis network with target word 'vaccino' and then emotion counts: ")
print(emo_counts)
print()


""" 7. Get a formamentis network about "vaccino" and print z-scores """
# baseline same as before
edges, vertex = emos.formamentis_network(text)
zscores = emos.zscores(edges, target_word = "vaccino")

print("7. Get a Formamentis network and get z-scores against loaded baseline, with filter on edges linked to 'vaccino':")
print(zscores)
print()


""" 8. What if we ask for the neighbors of "vaccino" without using formamentis? """
try:
    # baseline same as before
    zscores = emos.zscores(text, target_word = "vaccino")

except Exception as e:
    print("8. [text with target word?]", e)
    print()
    
    
""" 9. Loading a formamentis and asking z-scores is best when working with multiple files. 
       You can also just get emotion counts and ask to use formamentis networks as well. 
"""
# baseline same as before
zscores = emos.zscores(text, method = 'formamentis', target_word = "vaccino")

print("9. Get Z-scores from text through Formamentis, and filter the edges on 'vaccino':")
print(zscores)
print()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (26, 8))

emo_counts = emos.emotions(text, normalization_strategy = 'num_emotions')
emo_baseline = emos.baseline_distribution().emotions
zscores = emos.zscores(text)


emos.draw_plutchik(emo_counts, ax = ax[0], title = 'counts')
emos.draw_plutchik(emo_baseline, ax = ax[1], title = 'baseline')
emos.draw_plutchik(zscores, reject_range = (-1.96, 1.96), rescale = (-10, 10), ax = ax[2], title = 'against baseline');

print("On the left, the emotion distribution in the text.")
print("On the center, the emotion distribution in the baseline.")
print("On the right, the difference between the two previous distributions in z-scores.")

# %%
emos.stats(text)

# %%
emos.emotion_words(text, duplicates = True)

# %%
from emotionslib import EmoScores

emos = EmoScores(language = 'italian')
eng = EmoScores()

# %%
txtita = "Oggi non è buono, perciò mi sa che non vado al mare, non è giusto..." # giusto -> sleale?
emos.formamentis_network(txtita)
# Out:
# ['non', 'no', 'né']
# ([('andare', 'giusto'),
#   ('essere', 'sleale'),
#   ('essere', 'giusto'),
#   ('andare', 'essere'),
#   ('giusto', 'sleale'),
#   ('andare', 'sapere'),
#   ('giusto', 'essere'),
#   ('sleale', 'essere'),
#   ('mare', 'sapere'),
#   ('non', 'buono'),
#   ('essere', 'sapere'),
#   ('giusto', 'sapere'),
#   ('sleale', 'sapere'),
#   ('buono', 'sapere'),
#   ('andare', 'non'),
#   ('mare', 'non'),
#   ('essere', 'non'),
#   ('giusto', 'non'),
#   ('buono', 'non'),
#   ('sapere', 'non'),
#   ('non', 'sleale'),
#   ('non', 'giusto'),
#   ('sleale', 'non'),
#   ('andare', 'mare'),
#   ('andare', 'buono'),
#   ('non', 'essere'),
#   ('mare', 'buono'),
#   ('essere', 'buono'),
#   ('giusto', 'buono'),
#   ('sleale', 'buono'),
#   ('non', 'sapere')],
#  ['giusto', 'buono', 'andare', 'essere', 'non', 'sapere', 'sleale', 'mare'])

# %%
txteng = "Today I won't go, it's not accessible, it doesn't look fair..." #accessible -> inaccessible?
eng.formamentis_network(txteng)
# Out:
# ['no', 'neither', 'not', 'cannot', 'never', "can't", "won't", 'nothing', "don't", "doesn't", "didn't", "n't"]
# ([('it', 'look'),
#   ('wo', 'accessible'),
#   ("n't", 'it'),
#   ('I', "n't"),
#   ('not', 'accessible'),
#   ('look', 'accessible'),
#   ('look', 'I'),
#   ('wo', 'it'),
#   ('I', 'not'),
#   ('today', 'accessible'),
#   ('I', 'wo'),
#   ('fair', 'accessible'),
#   ('today', 'I'),
#   ('look', 'it'),
#   ("n't", 'fair'),
#   ("n't", 'look'),
#   ('today', 'it'),
#   ("n't", 'not'),
#   ('wo', "n't"),
#   ('it', 'accessible'),
#   ('fair', 'it'),
#   ('wo', 'not'),
#   ('look', "n't"),
#   ('look', 'fair'),
#   ('today', "n't"),
#   ('look', 'not'),
#   ('look', 'wo'),
#   ('I', 'accessible'),
#   ('today', 'not'),
#   ('today', 'look'),
#   ('today', 'wo'),
#   ('fair', 'not'),
#   ("n't", 'accessible'),
#   ('it', "n't"),
#   ('I', 'it'),
#   ('it', 'fair'),
#   ('it', 'not')],
#  ['today', 'it', 'accessible', "n't", 'I', 'fair', 'not', 'look', 'wo'])

# %%
obj = eng.formamentis_network(txteng)
obj = obj[0]

if type(obj) == tuple and type(obj[0][0]) == tuple:
    print('hey')
# Out:
# ['no', 'neither', 'not', 'cannot', 'never', "can't", "won't", 'nothing', "don't", "doesn't", "didn't", "n't"]

# %%
eng.zscores(eng.formamentis_network(txteng))
# Out:
# ['no', 'neither', 'not', 'cannot', 'never', "can't", "won't", 'nothing', "don't", "doesn't", "didn't", "n't"]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-eaf61f889cd4> in <module>
# ----> 1 eng.zscores(eng.formamentis_network(txteng))
#
# ~/Scrivania/pyplutchik/refactoring/emotionslib.py in zscores(self, obj, language, spacy_model, baseline, emotion_lexicon, duplicates, negation_strategy, antonyms, negations, n_samples, method, target_word, emotion_model, epsilon)
#     586
#     587
# --> 588         return es._zscores(obj,
#     589            language = language,
#     590            spacy_model = spacy_model,
#
# ~/Scrivania/pyplutchik/refactoring/emo_scores.py in _zscores(obj, language, spacy_model, baseline, emotion_lexicon, duplicates, negation_strategy, antonyms, negations, n_samples, method, target_word, emotion_model, wn, epsilon)
#     413
#     414     # count emotions in wordlist
# --> 415     emo_counts, n_emotionwords = _count_emotions(obj = obj,
#     416                                                 emotion_lexicon = emotion_lexicon,
#     417                                                 normalization_strategy = 'none',
#
# ~/Scrivania/pyplutchik/refactoring/emo_scores.py in _count_emotions(obj, emotion_lexicon, normalization_strategy, emotions, language, spacy_model, duplicates, negation_strategy, negations, antonyms, method, target_word, emotion_model, wn)
#     122         emotions = ['anger', 'trust', 'surprise', 'disgust', 'joy', 'sadness', 'fear', 'anticipation']
#     123
# --> 124     wordlist = _txl._load_object(obj = obj,
#     125                            language = language,
#     126                            spacy_model = spacy_model,
#
# ~/Scrivania/pyplutchik/refactoring/textloader.py in _load_object(obj, spacy_model, language, target_word, duplicates, negation_strategy, negations, antonyms, method, keepwords, stopwords, wn)
#     167
#     168     if type(obj) == tuple and type(obj[0][0]) == tuple:
# --> 169         raise ValueError("You inputed a tuple of two elements, the first one being a list of tuples. Perhaps you are using a formamentis network as input? Only edges should be used.")
#     170
#     171     if type(obj) == list:
#
# ValueError: You inputed a tuple of two elements, the first one being a list of tuples. Perhaps you are using a formamentis network as input? Only edges should be used.

# %%
eng.antonyms
# Out:
# {'ability': 'inability',
#  'abnormal': 'normal',
#  'abolish': 'establish',
#  'absence': 'presence',
#  'absent': 'present',
#  'absolute': 'relative',
#  'absorbent': 'nonabsorbent',
#  'abstain': 'consume',
#  'abstract': 'concrete',
#  'abundance': 'scarcity',
#  'abundant': 'scarce',
#  'accelerate': 'decelerate',
#  'acceleration': 'deceleration',
#  'accept': 'reject',
#  'acceptable': 'unacceptable',
#  'acceptance': 'rejection',
#  'accessible': 'inaccessible',
#  'accidentally': 'deliberately',
#  'accuracy': 'inaccuracy',
#  'accurate': 'inaccurate',
#  'accustomed': 'unaccustomed',
#  'acidity': 'alkalinity',
#  'acknowledged': 'unacknowledged',
#  'acquaintance': 'stranger',
#  'act': 'refrain',
#  'action': 'inaction',
#  'active': 'stative',
#  'activity': 'inactivity',
#  'actual': 'potential',
#  'acutely': 'chronically',
#  'adaptable': 'unadaptable',
#  'add': 'take away',
#  'addition': 'subtraction',
#  'additive': 'subtractive',
#  'adequacy': 'inadequacy',
#  'adequate': 'inadequate',
#  'adhesive': 'nonadhesive',
#  'adjective': 'substantive',
#  'admire': 'look down on',
#  'admissibility': 'inadmissibility',
#  'admissible': 'inadmissible',
#  'admit': 'reject',
#  'adult': 'juvenile',
#  'advance': 'retreat',
#  'advantage': 'disadvantage',
#  'advantageous': 'disadvantageous',
#  'adventurous': 'unadventurous',
#  'advisable': 'inadvisable',
#  'aesthetic': 'inaesthetic',
#  'affinity': 'consanguinity',
#  'affirm': 'negate',
#  'affirmation': 'reversal',
#  'affirmative': 'negative',
#  'afraid': 'unafraid',
#  'aft': 'fore',
#  'age': 'rejuvenate',
#  'aged': 'young',
#  'aggressive': 'unaggressive',
#  'agitated': 'unagitated',
#  'agitation': 'calmness',
#  'agnostic': 'gnostic',
#  'agree': 'disagree',
#  'agreeable': 'disagreeable',
#  'agreement': 'disagreement',
#  'aground': 'afloat',
#  'ahead': 'back',
#  'alarming': 'unalarming',
#  'alert': 'unalert',
#  'aligned': 'nonaligned',
#  'alignment': 'nonalignment',
#  'alike': 'unalike',
#  'aliquot': 'aliquant',
#  'alive': 'dead',
#  'allow': 'disallow',
#  'altered': 'unaltered',
#  'alternate': 'opposite',
#  'amateur': 'professional',
#  'ambiguity': 'unambiguity',
#  'ambiguous': 'unambiguous',
#  'ambitious': 'unambitious',
#  'amicable': 'hostile',
#  'amphibious': 'terrestrial',
#  'amply': 'meagerly',
#  'anal': 'oral',
#  'analogous': 'homologous',
#  'analogue': 'digital',
#  'analysis': 'synthesis',
#  'analytic': 'synthetic',
#  'analyze': 'synthesize',
#  'ancestor': 'descendant',
#  'angry': 'unangry',
#  'angular': 'rounded',
#  'anhydrous': 'hydrous',
#  'animate': 'inanimate',
#  'animated': 'unanimated',
#  'anonymous': 'onymous',
#  'answer': 'question',
#  'antagonist': 'synergist',
#  'antagonistic': 'synergistic',
#  'antecedent': 'subsequent',
#  'anterior': 'posterior',
#  'antiseptic': 'septic',
#  'apex': 'antapex',
#  'apologetic': 'unapologetic',
#  'appearance': 'disappearance',
#  'applicability': 'inapplicability',
#  'appreciation': 'depreciation',
#  'approbation': 'disapprobation',
#  'approval': 'disapproval',
#  'approve': 'disapprove',
#  'aptitude': 'inaptitude',
#  'aquatic': 'amphibious',
#  'aqueous': 'igneous',
#  'argumentative': 'unargumentative',
#  'arm': 'disarm',
#  'armament': 'disarmament',
#  'armed': 'unarmed',
#  'armored': 'unarmored',
#  'arrange': 'disarrange',
#  'arranged': 'disarranged',
#  'arrive': 'leave',
#  'artful': 'artless',
#  'articulate': 'inarticulate',
#  'ascend': 'descend',
#  'ascent': 'descent',
#  'ashamed': 'unashamed',
#  'asleep': 'awake',
#  'assemble': 'disassemble',
#  'assembly': 'disassembly',
#  'assent': 'dissent',
#  'assimilate': 'dissimilate',
#  'associate': 'dissociate',
#  'association': 'disassociation',
#  'astigmatism': 'stigmatism',
#  'astringent': 'nonastringent',
#  'asymmetry': 'symmetry',
#  'atheism': 'theism',
#  'attach': 'detach',
#  'attack': 'defend',
#  'attendance': 'nonattendance',
#  'attention': 'inattention',
#  'attentive': 'inattentive',
#  'attraction': 'repulsion',
#  'attractiveness': 'unattractiveness',
#  'attributable': 'unattributable',
#  'audible': 'inaudible',
#  'augmentation': 'diminution',
#  'aunt': 'uncle',
#  'auspicious': 'inauspicious',
#  'authorized': 'unauthorized',
#  'automatic': 'manual',
#  'avoid': 'confront',
#  'awake': 'asleep',
#  'awaken': 'cause to sleep',
#  'awkwardness': 'gracefulness',
#  'back': 'veer',
#  'background': 'foreground',
#  'backward': 'forward',
#  'bad': 'good',
#  'badly': 'well',
#  'badness': 'goodness',
#  'balance': 'unbalance',
#  'balanced': 'unbalanced',
#  'bar': 'unbar',
#  'bear': 'bull',
#  'bearing': 'nonbearing',
#  'beautiful': 'ugly',
#  'beautify': 'uglify',
#  'beauty': 'ugliness',
#  'begin': 'end',
#  'beginning': 'middle',
#  'belief': 'unbelief',
#  'believe': 'disbelieve',
#  'belt': 'unbelt',
#  'bend': 'unbend',
#  'benevolence': 'malevolence',
#  'benign': 'malignant',
#  'bequeath': 'disinherit',
#  'biennial': 'annual',
#  'big': 'small',
#  'bind': 'unbind',
#  'birth': 'death',
#  'bisexual': 'homosexual',
#  'black': 'white',
#  'blame': 'absolve',
#  'bless': 'curse',
#  'blessed': 'cursed',
#  'blind': 'sighted',
#  'block': 'unblock',
#  'blond': 'brunet',
#  'bloodless': 'bloody',
#  'bloody': 'bloodless',
#  'blur': 'focus',
#  'boil': 'freeze',
#  'bold': 'timid',
#  'boldness': 'timidity',
#  'bolt': 'unbolt',
#  'bony': 'boneless',
#  'boo': 'applaud',
#  'bore': 'interest',
#  'borrow': 'lend',
#  'borrower': 'lender',
#  'bottom': 'top',
#  'bottomless': 'bottomed',
#  'bounce': 'clear',
#  'bound': 'unbound',
#  'bowed': 'plucked',
#  'box': 'unbox',
#  'boy': 'girl',
#  'boycott': 'patronize',
#  'braid': 'unbraid',
#  'break': 'repair',
#  'breakable': 'unbreakable',
#  'bridle': 'unbridle',
#  'brighten': 'darken',
#  'brightness': 'dullness',
#  'bring': 'take away',
#  'broken': 'unbroken',
#  'brother': 'sister',
#  'brotherly': 'sisterly',
#  'buckle': 'unbuckle',
#  'bull': 'bear',
#  'burden': 'unburden',
#  'buried': 'unburied',
#  'busy': 'idle',
#  'button': 'unbutton',
#  'buy': 'sell',
#  'calm': 'stormy',
#  'calmness': 'agitation',
#  'capability': 'incapability',
#  'capable': 'incapable',
#  'capacity': 'incapacity',
#  'captor': 'liberator',
#  'cardinal': 'ordinal',
#  'careful': 'careless',
#  'carefully': 'carelessly',
#  'carelessness': 'carefulness',
#  'carnivorous': 'herbivorous',
#  'cash': 'credit',
#  'catabolism': 'anabolism',
#  'caudal': 'cephalic',
#  'caution': 'incaution',
#  'cautious': 'incautious',
#  'cautiously': 'incautiously',
#  'cellular': 'noncellular',
#  'center': 'left',
#  'central': 'peripheral',
#  'centrality': 'marginality',
#  'centralization': 'decentralization',
#  'centralize': 'decentralize',
#  'centrally': 'peripherally',
#  'centrifugal': 'centripetal',
#  'cerebral': 'emotional',
#  'certainty': 'uncertainty',
#  'certify': 'decertify',
#  'chain': 'unchain',
#  'change': 'stay',
#  'changeable': 'unchangeable',
#  'changed': 'unchanged',
#  'characteristic': 'uncharacteristic',
#  'charge': 'pay cash',
#  'charitable': 'uncharitable',
#  'chartered': 'unchartered',
#  'cheap': 'expensive',
#  'cheer': 'complain',
#  'cheerful': 'depressing',
#  'cheerfulness': 'uncheerfulness',
#  'child': 'parent',
#  'chromatic': 'diatonic',
#  'chronic': 'acute',
#  'citizen': 'noncitizen',
#  'civil': 'uncivil',
#  'civilian': 'serviceman',
#  'civility': 'incivility',
#  'civilized': 'noncivilized',
#  'claim': 'forfeit',
#  'clarify': 'obfuscate',
#  'clarity': 'opacity',
#  'clasp': 'unclasp',
#  'classical': 'nonclassical',
#  'classification': 'declassification',
#  'classify': 'declassify',
#  'clean': 'unclean',
#  'cleanliness': 'uncleanliness',
#  'clearness': 'unclearness',
#  'clergy': 'laity',
#  'clergyman': 'layman',
#  'clip': 'unclip',
#  'clog': 'unclog',
#  'close': 'open',
#  'closed': 'open',
#  'closeness': 'openness',
#  'cloudy': 'clear',
#  'clutter': 'unclutter',
#  'coastal': 'inland',
#  'coherence': 'incoherence',
#  'coherent': 'incoherent',
#  'coil': 'uncoil',
#  'coiled': 'uncoiled',
#  'cold': 'hot',
#  'coldness': 'hotness',
#  'collateral': 'lineal',
#  'collected': 'uncollected',
#  'collective': 'distributive',
#  'color': 'discolor',
#  'colored': 'uncolored',
#  'colorless': 'colorful',
#  'combined': 'uncombined',
#  'combustible': 'noncombustible',
#  'comedy': 'tragedy',
#  'comfort': 'discomfort',
#  'commensurate': 'incommensurate',
#  'commercial': 'noncommercial',
#  'committed': 'uncommitted',
#  'common': 'uncommon',
#  'communicate': 'excommunicate',
#  'communicative': 'uncommunicative',
#  'compact': 'loose',
#  'comparable': 'incomparable',
#  'compassionate': 'uncompassionate',
#  'compatibility': 'incompatibility',
#  'compatible': 'incompatible',
#  'competence': 'incompetence',
#  'competent': 'incompetent',
#  'competition': 'cooperation',
#  'competitive': 'noncompetitive',
#  'complain': 'cheer',
#  'completeness': 'incompleteness',
#  'complex': 'simple',
#  'complexity': 'simplicity',
#  'compliance': 'noncompliance',
#  'compliant': 'defiant',
#  'complicate': 'simplify',
#  'composed': 'discomposed',
#  'composure': 'discomposure',
#  'compound': 'simple',
#  'comprehension': 'incomprehension',
#  'comprehensive': 'noncomprehensive',
#  'compress': 'decompress',
#  'compressible': 'incompressible',
#  'compression': 'decompression',
#  'con': 'pro',
#  'concave': 'convex',
#  'concealed': 'unconcealed',
#  'conceit': 'humility',
#  'concentrate': 'deconcentrate',
#  'concentration': 'distribution',
#  'concentric': 'eccentric',
#  'conception': 'misconception',
#  'concern': 'unconcern',
#  'concerned': 'unconcerned',
#  'concise': 'prolix',
#  'concrete': 'abstract',
#  'conditional': 'unconditional',
#  'conditionally': 'unconditionally',
#  'conditioned': 'unconditioned',
#  'conductor': 'insulator',
#  'confidence': 'diffidence',
#  'confident': 'diffident',
#  'confine': 'free',
#  'confined': 'unconfined',
#  'confirmed': 'unconfirmed',
#  'conformity': 'nonconformity',
#  'confront': 'avoid',
#  'congenial': 'uncongenial',
#  'conjunctive': 'disjunctive',
#  'connect': 'disconnect',
#  'connected': 'unconnected',
#  'conscientious': 'unconscientious',
#  'consciousness': 'unconsciousness',
#  'consequence': 'inconsequence',
#  'conservative': 'liberal',
#  'conserve': 'waste',
#  'considerable': 'inconsiderable',
#  'considerate': 'inconsiderate',
#  'consistency': 'inconsistency',
#  'consistent': 'inconsistent',
#  'consonant': 'vowel',
#  'conspicuous': 'inconspicuous',
#  'constancy': 'inconstancy',
#  'constant': 'inconstant',
#  'constitutional': 'unconstitutional',
#  'construction': 'misconstruction',
#  'consume': 'abstain',
#  'contaminate': 'decontaminate',
#  'contaminated': 'uncontaminated',
#  'contamination': 'decontamination',
#  'contemptible': 'estimable',
#  'content': 'discontent',
#  'continent': 'incontinent',
#  'continental': 'intercontinental',
#  'continual': 'sporadic',
#  'continuance': 'discontinuance',
#  'continuation': 'discontinuation',
#  'continue': 'discontinue',
#  'continued': 'discontinued',
#  'continuity': 'discontinuity',
#  'continuous': 'discontinuous',
#  'contract': 'expand',
#  'contracted': 'expanded',
#  'contraction': 'expansion',
#  'controversial': 'uncontroversial',
#  'convenience': 'inconvenience',
#  'convenient': 'inconvenient',
#  'conventional': 'unconventional',
#  'converge': 'diverge',
#  'convergence': 'divergence',
#  'convergent': 'divergent',
#  'convertible': 'inconvertible',
#  'convex': 'concave',
#  'convict': 'acquit',
#  'conviction': 'acquittal',
#  'convinced': 'unconvinced',
#  'convincing': 'unconvincing',
#  'cool': 'warm',
#  'cooperation': 'competition',
#  'cooperative': 'uncooperative',
#  'cork': 'uncork',
#  'corporeal': 'incorporeal',
#  'correctness': 'incorrectness',
#  'corrupt': 'incorrupt',
#  'cortex': 'medulla',
#  'cosmopolitan': 'provincial',
#  'couple': 'uncouple',
#  'courage': 'cowardice',
#  'courteous': 'discourteous',
#  'courtesy': 'discourtesy',
#  'cover': 'uncover',
#  'covered': 'bare',
#  'covert': 'overt',
#  'cowardice': 'courage',
#  'cowardly': 'brave',
#  'crate': 'uncrate',
#  'creative': 'uncreative',
#  'credibility': 'incredibility',
#  'credible': 'incredible',
#  'credit': 'debit',
#  'creditor': 'debtor',
#  'crescendo': 'decrescendo',
#  'criticize': 'praise',
#  'cross': 'uncross',
#  'crossed': 'uncrossed',
#  'crowded': 'uncrowded',
#  'crucial': 'noncrucial',
#  'cry': 'laugh',
#  'crystalline': 'noncrystalline',
#  'cultivated': 'uncultivated',
#  'curable': 'incurable',
#  'current': 'noncurrent',
#  'curse': 'bless',
#  'cursed': 'blessed',
#  'curve': 'straight line',
#  'curved': 'straight',
#  'cut': 'uncut',
#  'cyclone': 'anticyclone',
#  'danger': 'safety',
#  'dangerous': 'safe',
#  'dark': 'light',
#  'darken': 'lighten',
#  'darkness': 'lightness',
#  'daughter': 'son',
#  'day': 'night',
#  'deaf': 'hearing',
#  'death': 'birth',
#  'debit': 'credit',
#  'debtor': 'creditor',
#  'deceive': 'undeceive',
#  'decency': 'indecency',
#  'decent': 'indecent',
#  'deciduous': 'evergreen',
#  'decision': 'indecision',
#  'decisive': 'indecisive',
#  'declaratory': 'interrogatory',
#  'decline': 'improvement',
#  'decorum': 'indecorum',
#  'decrease': 'increase',
#  'decreased': 'increased',
#  'decreasing': 'increasing',
#  'decrement': 'increment',
#  'default': 'pay up',
#  'defeat': 'victory',
#  'defeated': 'undefeated',
#  'defend': 'prosecute',
#  'defendant': 'plaintiff',
#  'defense': 'prosecution',
#  'defensive': 'offensive',
#  'defiant': 'compliant',
#  'deficit': 'lead',
#  'defined': 'undefined',
#  'deflate': 'inflate',
#  'deflation': 'inflation',
#  'defy': 'lend oneself',
#  'degrade': 'aggrade',
#  'delay': 'rush',
#  'demand': 'supply',
#  'demanding': 'undemanding',
#  'demonstrative': 'undemonstrative',
#  'deny': 'allow',
#  'depart': 'stay',
#  'dependent': 'independent',
#  'deposit': 'withdraw',
#  'depreciate': 'appreciate',
#  'depreciation': 'appreciation',
#  'depress': 'elate',
#  'depressing': 'cheerful',
#  'depression': 'elation',
#  'descend': 'ascend',
#  'descendant': 'ancestor',
#  'descending': 'ascending',
#  'descent': 'ascent',
#  'descriptive': 'undescriptive',
#  'designed': 'undesigned',
#  'desirability': 'undesirability',
#  'desirable': 'undesirable',
#  'desirous': 'undesirous',
#  'despair': 'hope',
#  'desperate': 'hope',
#  'desperation': 'hope',
#  'destroyed': 'preserved',
#  'destructive': 'constructive',
#  'detach': 'attach',
#  'detached': 'attached',
#  'deteriorate': 'recuperate',
#  'determinable': 'indeterminable',
#  'determinate': 'indeterminate',
#  'determined': 'undetermined',
#  'development': 'nondevelopment',
#  'deviate': 'conform',
#  'devolution': 'evolution',
#  'die': 'be born',
#  'differ': 'equal',
#  'difference': 'sameness',
#  'difficult': 'easy',
#  'difficulty': 'ease',
#  'dignified': 'undignified',
#  'diligent': 'negligent',
#  'diluted': 'undiluted',
#  'dilution': 'concentration',
#  'diminution': 'augmentation',
#  'diplomatic': 'undiplomatic',
#  'directly': 'indirectly',
#  'dirty': 'clean',
#  'disable': 'enable',
#  'disadvantage': 'advantage',
#  'disagree': 'agree',
#  'disagreeable': 'agreeable',
#  'disagreement': 'agreement',
#  'disallow': 'allow',
#  'disappear': 'appear',
#  'disappearance': 'appearance',
#  'disapproval': 'approval',
#  'disapprove': 'approve',
#  'disarm': 'arm',
#  'disbelieve': 'believe',
#  'discernible': 'indiscernible',
#  'discerning': 'undiscerning',
#  'discharge': 'enlist',
#  'discipline': 'indiscipline',
#  'disclaim': 'claim',
#  'discolor': 'color',
#  'discomfort': 'comfort',
#  'disconnect': 'connect',
#  'discontent': 'content',
#  'discontinuance': 'continuance',
#  'discontinue': 'continue',
#  'discontinuity': 'continuity',
#  'discontinuous': 'continuous',
#  'discourage': 'encourage',
#  'discouragement': 'encouragement',
#  'discreet': 'indiscreet',
#  'discriminate': 'indiscriminate',
#  'discriminating': 'undiscriminating',
#  'disengage': 'engage',
#  'dishonest': 'honest',
#  'dishonesty': 'honesty',
#  'dishonor': 'honor',
#  'disinfect': 'infect',
#  'disingenuous': 'ingenuous',
#  'disintegrate': 'integrate',
#  'disjunctive': 'conjunctive',
#  'dislike': 'liking',
#  'disliked': 'liked',
#  'dislodge': 'lodge',
#  'disobedience': 'obedience',
#  'disobedient': 'obedient',
#  'disobey': 'obey',
#  'disorder': 'order',
#  'disorderly': 'orderly',
#  'disorganized': 'organized',
#  'disparage': 'flatter',
#  'displeased': 'pleased',
#  'dispose': 'indispose',
#  'disprove': 'prove',
#  'disqualify': 'qualify',
#  'disreputable': 'reputable',
#  'disrepute': 'repute',
#  'disrespect': 'respect',
#  'disrespectful': 'respectful',
#  'dissatisfaction': 'satisfaction',
#  'dissent': 'assent',
#  'disservice': 'service',
#  'dissimilar': 'similar',
#  'dissonance': 'harmony',
#  'dissuade': 'persuade',
#  'distal': 'proximal',
#  'distant': 'close',
#  'distinguishable': 'indistinguishable',
#  'distribution': 'concentration',
#  'distrust': 'trust',
#  'diurnal': 'nocturnal',
#  'diverge': 'converge',
#  'divergence': 'convergence',
#  'divergent': 'convergent',
#  'diversified': 'undiversified',
#  'diversify': 'specialize',
#  'divest': 'invest',
#  'divide': 'unite',
#  'divided': 'united',
#  'divisible': 'indivisible',
#  'docile': 'stubborn',
#  'dock': 'undock',
#  'domestic': 'undomestic',
#  'dominant': 'subordinate',
#  'dormant': 'active',
#  'dorsal': 'ventral',
#  'double': 'single',
#  'dove': 'hawk',
#  'drained': 'undrained',
#  'dramatic': 'undramatic',
#  'driver': 'nondriver',
#  'drunkenness': 'soberness',
#  'dry': 'wet',
#  'dryness': 'wetness',
#  'due': 'undue',
#  'dull': 'sharpen',
#  'dying': 'nascent',
#  'dynamic': 'undynamic',
#  'eager': 'uneager',
#  'early': 'middle',
#  'earthly': 'heavenly',
#  'ease': 'difficulty',
#  'easy': 'uneasy',
#  'ebb': 'tide',
#  'eccentric': 'concentric',
#  'eccentricity': 'concentricity',
#  'edible': 'inedible',
#  'educated': 'uneducated',
#  'effective': 'ineffective',
#  'effectually': 'ineffectually',
#  'efficacious': 'inefficacious',
#  'efficacy': 'inefficacy',
#  'efficiency': 'inefficiency',
#  'efficient': 'inefficient',
#  'egress': 'ingress',
#  'elastic': 'inelastic',
#  'elasticity': 'inelasticity',
#  'elated': 'dejected',
#  'elegance': 'inelegance',
#  'elegant': 'inelegant',
#  'eligible': 'ineligible',
#  'embark': 'disembark',
#  'embarrassment': 'disembarrassment',
#  'emigrate': 'immigrate',
#  'emit': 'absorb',
#  'emotional': 'unemotional',
#  'empirical': 'theoretical',
#  'employer': 'employee',
#  'employment': 'unemployment',
#  'emptiness': 'fullness',
#  'empty': 'full',
#  'enable': 'disable',
#  'enchant': 'disenchant',
#  'enchanted': 'disenchanted',
#  'encode': 'decode',
#  'encourage': 'discourage',
#  'encouragement': 'discouragement',
#  'end': 'beginning',
#  'endemic': 'ecdemic',
#  'ending': 'beginning',
#  'endowed': 'unendowed',
#  'energetic': 'lethargic',
#  'enforce': 'exempt',
#  'engage': 'disengage',
#  'engagement': 'non-engagement',
#  'enjoy': 'suffer',
#  'enlightenment': 'unenlightenment',
#  'enlist': 'discharge',
#  'enliven': 'deaden',
#  'enrich': 'impoverish',
#  'enter': 'exit',
#  'enterprising': 'unenterprising',
#  'epidemic': 'ecdemic',
#  'equal': 'unequal',
#  'equality': 'inequality',
#  'equally': 'unequally',
#  'equatorial': 'polar',
#  'equilibrium': 'disequilibrium',
#  'equitable': 'inequitable',
#  'equity': 'inequity',
#  'equivalence': 'nonequivalence',
#  'equivocal': 'unequivocal',
#  'erase': 'record',
#  'erect': 'unerect',
#  'escalate': 'de-escalate',
#  'esoteric': 'exoteric',
#  'essential': 'inessential',
#  'establish': 'abolish',
#  'established': 'unestablished',
#  'esteem': 'disesteem',
#  'ethical': 'unethical',
#  'eugenics': 'dysgenics',
#  'euphemism': 'dysphemism',
#  'eventful': 'uneventful',
#  'evergreen': 'deciduous',
#  'evil': 'good',
#  'evolution': 'devolution',
#  'excitable': 'unexcitable',
#  'excited': 'unexcited',
#  'exciting': 'unexciting',
#  'exclude': 'include',
#  'exclusion': 'inclusion',
#  'exempt': 'nonexempt',
#  'exhale': 'inhale',
#  'exhausted': 'unexhausted',
#  'existence': 'nonexistence',
#  'existent': 'nonexistent',
#  'exit': 'enter',
#  'expand': 'contract',
#  'expanded': 'contracted',
#  'expansion': 'contraction',
#  'expansive': 'unexpansive',
#  'expatriate': 'repatriate',
#  'expected': 'unexpected',
#  'expediency': 'inexpediency',
#  'expedient': 'inexpedient',
#  'expensive': 'cheap',
#  'experience': 'inexperience',
#  'experienced': 'inexperienced',
#  'expired': 'unexpired',
#  'explode': 'implode',
#  'explosive': 'nonexplosive',
#  'export': 'import',
#  'express': 'local',
#  'extant': 'extinct',
#  'extended': 'unextended',
#  'extension': 'flexion',
#  'extensive': 'intensive',
#  'exterior': 'interior',
#  'external': 'internal',
#  'externally': 'internally',
#  'extinct': 'extant',
#  'extinguish': 'ignite',
#  'extramural': 'intramural',
#  'extraordinary': 'ordinary',
#  'extrinsic': 'intrinsic',
#  'failing': 'passing',
#  'failure': 'success',
#  'fair': 'unfair',
#  'fairly': 'unfairly',
#  'faithful': 'unfaithful',
#  'fall': 'rise',
#  'fallible': 'infallible',
#  'falling': 'rising',
#  'falsehood': 'truth',
#  'falsify': 'correct',
#  'falsity': 'truth',
#  'fame': 'infamy',
#  'familiar': 'unfamiliar',
#  'familiarity': 'unfamiliarity',
#  'fancy': 'plain',
#  'fashionable': 'unfashionable',
#  'fasten': 'unfasten',
#  'fat': 'thin',
#  'fatal': 'nonfatal',
#  'father': 'mother',
#  'fatty': 'nonfat',
#  'fauna': 'flora',
#  'favorable': 'unfavorable',
#  'fear': 'fearlessness',
#  'fearfully': 'fearlessly',
#  'feasibility': 'infeasibility',
#  'febrile': 'afebrile',
#  'federal': 'unitary',
#  'feed': 'starve',
#  'felicity': 'infelicity',
#  'female': 'male',
#  'feminine': 'neuter',
#  'femininity': 'masculinity',
#  'fertile': 'sterile',
#  'fidelity': 'infidelity',
#  'figurative': 'literal',
#  'figure': 'ground',
#  'fill': 'empty',
#  'financial': 'nonfinancial',
#  'find': 'lose',
#  'finish': 'start',
#  'finite': 'infinite',
#  'fire': 'hire',
#  'fissile': 'nonfissile',
#  'fitness': 'unfitness',
#  'fixed': 'unfixed',
#  'flashback': 'flash-forward',
#  'flat': 'natural',
#  'flatten': 'sharpen',
#  'flattering': 'unflattering',
#  'flexibility': 'inflexibility',
#  'flexible': 'inflexible',
#  'flexion': 'extension',
#  'float': 'sink',
#  'flora': 'fauna',
#  'flowering': 'flowerless',
#  'fluency': 'disfluency',
#  'focus': 'blur',
#  'foe': 'friend',
#  'fold': 'unfold',
#  'follow': 'precede',
#  'follower': 'leader',
#  'folly': 'wisdom',
#  'foolish': 'wise',
#  'foot': 'head',
#  'forbid': 'permit',
#  'fore': 'aft',
#  'foreground': 'background',
#  'foreign': 'native',
#  'forfeit': 'claim',
#  'forget': 'remember',
#  'forgiving': 'unforgiving',
#  'formalism': 'imitation',
#  'formality': 'informality',
#  'formed': 'unformed',
#  'forte': 'piano',
#  'fortunate': 'unfortunate',
#  'forward': 'reverse',
#  'foul': 'fair',
#  'found': 'lost',
#  'fractional': 'whole',
#  'fragrant': 'malodorous',
#  'fraternal': 'identical',
#  'freelance': 'salaried',
#  'freeze': 'unfreeze',
#  'frequent': 'infrequent',
#  'frequently': 'infrequently',
#  'friend': 'foe',
#  'friendliness': 'unfriendliness',
#  'friendly': 'unfriendly',
#  'frivolous': 'serious',
#  'front': 'rear',
#  'frozen': 'unfrozen',
#  'fruitful': 'unfruitful',
#  'full': 'thin',
#  'fullness': 'emptiness',
#  'function': 'malfunction',
#  'functional': 'organic',
#  'fuse': 'defuse',
#  'future': 'present',
#  'gain': 'reduce',
#  'gaseous': 'solid',
#  'gather': 'spread',
#  'general': 'specific',
#  'generality': 'particularity',
#  'generally': 'specifically',
#  'generative': 'consumptive',
#  'generic': 'varietal',
#  'generosity': 'stinginess',
#  'generous': 'ungenerous',
#  'genuine': 'counterfeit',
#  'girl': 'boy',
#  'glad': 'sad',
#  'good': 'evil',
#  'goodness': 'evilness',
#  'graceful': 'awkward',
#  'gracious': 'ungracious',
#  'graciously': 'ungraciously',
#  'gradual': 'sudden',
#  'grassy': 'grassless',
#  'grateful': 'ungrateful',
#  'gratitude': 'ingratitude',
#  'gravitation': 'levitation',
#  'gravity': 'levity',
#  'greater': 'lesser',
#  'green': 'ripe',
#  'gregarious': 'ungregarious',
#  'gross': 'net',
#  'ground': 'figure',
#  'grudgingly': 'ungrudgingly',
#  'guilt': 'innocence',
#  'guilty': 'innocent',
#  'hairy': 'hairless',
#  'half': 'whole',
#  'happily': 'unhappily',
#  'happiness': 'unhappiness',
#  'happy': 'unhappy',
#  'harden': 'soften',
#  'hardened': 'soft',
#  'hardness': 'softness',
#  'hardware': 'software',
#  'harmful': 'harmless',
#  'harmony': 'dissonance',
#  'harness': 'unharness',
#  'hate': 'love',
#  'hateful': 'lovable',
#  'hawk': 'dove',
#  'head': 'tail',
#  'healthful': 'unhealthful',
#  'healthy': 'unhealthy',
#  'hearing': 'deaf',
#  'heat': 'cool',
#  'heavenly': 'earthly',
#  'heavily': 'lightly',
#  'heaviness': 'lightness',
#  'helpful': 'unhelpful',
#  'heterogeneity': 'homogeneity',
#  'hibernate': 'aestivate',
#  'hide': 'show',
#  'hierarchical': 'nonhierarchical',
#  'high': 'low spirits',
#  'highland': 'lowland',
#  'hire': 'fire',
#  'hit': 'miss',
#  'hold': 'let go of',
#  'holiness': 'unholiness',
#  'hollow': 'solid',
#  'holy': 'unholy',
#  'homeopathic': 'allopathic',
#  'homeopathy': 'allopathy',
#  'homogeneity': 'heterogeneity',
#  'homogeneous': 'heterogeneous',
#  'homologous': 'autologous',
#  'homosexual': 'bisexual',
#  'honest': 'dishonest',
#  'honesty': 'dishonesty',
#  'honor': 'dishonor',
#  'honorable': 'dishonorable',
#  'hook': 'unhook',
#  'hope': 'desperation',
#  'hopeful': 'hopeless',
#  'hopeless': 'hopeful',
#  'hopelessness': 'hopefulness',
#  'horizontal': 'vertical',
#  'hospitality': 'inhospitality',
#  'hostile': 'friendly',
#  'hot': 'cold',
#  'human': 'nonhuman',
#  'humane': 'inhumane',
#  'humble': 'proud',
#  'humility': 'pride',
#  'humorous': 'humorless',
#  'hungry': 'thirsty',
#  'hurried': 'unhurried',
#  'identical': 'fraternal',
#  'idle': 'work',
#  'igneous': 'aqueous',
#  'ignite': 'extinguish',
#  'ignore': 'notice',
#  'ill': 'well',
#  'illegal': 'legal',
#  'illegality': 'legality',
#  'illegible': 'legible',
#  'illegitimate': 'legitimate',
#  'illicit': 'licit',
#  'illiterate': 'literate',
#  'illness': 'wellness',
#  'illogical': 'logical',
#  'imitation': 'formalism',
#  'immaterial': 'material',
#  'immature': 'mature',
#  'immaturity': 'maturity',
#  'immeasurable': 'measurable',
#  'immeasurably': 'measurably',
#  'immediacy': 'mediacy',
#  'immersion': 'emersion',
#  'immoral': 'moral',
#  'immorality': 'morality',
#  'immortal': 'mortal',
#  'immortality': 'mortality',
#  'immutable': 'mutable',
#  'impartial': 'partial',
#  'impartiality': 'partiality',
#  'impassable': 'passable',
#  'impatience': 'patience',
#  'impatient': 'patient',
#  'impenetrable': 'penetrable',
#  'imperative': 'beseeching',
#  'imperceptible': 'perceptible',
#  'imperfection': 'perfection',
#  'imperfectly': 'perfectly',
#  'impermeable': 'permeable',
#  'impermissible': 'permissible',
#  'impersonal': 'personal',
#  'impervious': 'pervious',
#  'implacable': 'placable',
#  'impolite': 'polite',
#  'import': 'export',
#  'importance': 'unimportance',
#  'important': 'unimportant',
#  'impossibility': 'possibility',
#  'impossible': 'possible',
#  'impotence': 'potence',
#  'impotent': 'potent',
#  'impressionable': 'unimpressionable',
#  ...}
