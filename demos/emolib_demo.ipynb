# %%
import matplotlib
from emolib import EmoScores

# %%
emos = EmoScores()

# %%
sample_text = """In this text, we prefer dogs becase they are happy and dogs are positive.
Good dogs make good friends. Cats however are bad and have negative links. We dislike cats."""
fmnt = emos.formamentis_network(sample_text)

# %%
fmnt
# Out:
# FormamentisNetwork(edges=[('text', 'we'), ('we', 'dog'), ('cat', 'bad'), ('prefer', 'they'), ('negative', 'link'), ('good', 'dog'), ('we', 'cat'), ('positive', 'they'), ('positive', 'prefer'), ('dog', 'prefer'), ('happy', 'prefer'), ('dog', 'they'), ('good', 'friend'), ('cat', 'link'), ('we', 'dislike'), ('text', 'prefer'), ('we', 'prefer'), ('prefer', 'dog'), ('happy', 'they'), ('we', 'they'), ('happy', 'positive'), ('dog', 'friend'), ('dislike', 'cat'), ('dog', 'positive'), ('dog', 'good'), ('bad', 'link'), ('happy', 'we'), ('text', 'dog'), ('happy', 'dog')], vertices=['good', 'friend', 'they', 'negative', 'positive', 'text', 'link', 'bad', 'prefer', 'we', 'dog', 'dislike', 'happy', 'cat'])

# %%
emos.draw_formamentis(fmnt)
# Out:
# ALPHAS:  <class 'float'> 29 [0.3, 0.5, 0.3, 0.3, 0.3, 0.3, 0.5, 0.3, 0.3, 0.5, 0.3, 0.5, 0.3, 0.3, 0.3, 0.5, 0.5, 0.5, 0.3, 0.5, 0.3, 0.3, 0.5, 0.5, 0.3, 0.3, 0.5, 0.5, 0.5]
# [<class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>, <class 'float'>]
# lw:  <class 'int'> 29 [1, 1, 1, 3, 1, 3, 1, 1, 1, 1, 3, 1, 3, 1, 1, 1, 1, 3, 3, 1, 3, 1, 1, 1, 1, 1, 3, 1, 3]

# %%
bag_of_words_dog = " ".join([pair[1] for pair in fmnt.edges if pair[0].lower() == "dog"])
bag_of_words_cat = " ".join([pair[1] for pair in fmnt.edges if pair[0].lower() == "cat"])

# %%
zscores = emos.zscores(bag_of_words_dog)
emos.draw_plutchik(zscores, rescale = (-10, 10), title = 'Dog')
# Out:
# /home/finley/miniconda3/envs/cognet/lib/python3.7/site-packages/descartes/patch.py:65: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   for t in polygon])

# %%
zscores = emos.zscores(bag_of_words_cat)
emos.draw_plutchik(zscores, rescale = (-10, 10), title = 'Cat')
