# %%
import matplotlib
from emoatlas import EmoScores

# %%
emos = EmoScores(spacy_model='en_core_web_md')

# %%
sample_text = """In this text, we prefer dogs becase they are happy and dogs are positive.
Good dogs make good friends. Cats however are bad and have negative links. We dislike cats."""
fmnt = emos.formamentis_network(sample_text)

# %%
fmnt.vertices
# Out:
# ['they',
#  'bad',
#  'happy',
#  'we',
#  'good',
#  'negative',
#  'prefer',
#  'dislike',
#  'cat',
#  'friend',
#  'dog',
#  'text',
#  'positive',
#  'link']

# %%
fmnt.edges
# Out:
# [('prefer', 'they'),
#  ('text', 'we'),
#  ('dog', 'they'),
#  ('happy', 'they'),
#  ('happy', 'prefer'),
#  ('happy', 'positive'),
#  ('happy', 'we'),
#  ('dog', 'positive'),
#  ('dog', 'prefer'),
#  ('positive', 'they'),
#  ('positive', 'prefer'),
#  ('dog', 'friend'),
#  ('dog', 'good'),
#  ('cat', 'link'),
#  ('bad', 'link'),
#  ('prefer', 'text'),
#  ('dog', 'text'),
#  ('prefer', 'we'),
#  ('dog', 'we'),
#  ('they', 'we'),
#  ('dog', 'happy'),
#  ('friend', 'good'),
#  ('bad', 'cat'),
#  ('link', 'negative'),
#  ('cat', 'dislike'),
#  ('dislike', 'we'),
#  ('cat', 'we')]

# %%
emos.draw_formamentis(fmnt)

# %%
bag_of_words_dog = " ".join([pair[1] for pair in fmnt.edges if pair[0].lower() == "dog"])
bag_of_words_cat = " ".join([pair[1] for pair in fmnt.edges if pair[0].lower() == "cat"])

# %%
zscores = emos.zscores(bag_of_words_dog)
emos.draw_plutchik(zscores, rescale = (-10, 10), title = 'Dog')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/Salvatore/Documents/GitHub/emoatlas/emolib_demo.ipynb Cella 8 line 2
#       <a href='vscode-notebook-cell:/Users/Salvatore/Documents/GitHub/emoatlas/emolib_demo.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> zscores = emos.zscores(bag_of_words_dog)
# ----> <a href='vscode-notebook-cell:/Users/Salvatore/Documents/GitHub/emoatlas/emolib_demo.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> emos.draw_plutchik(zscores, rescale = (-10, 10), title = 'Dog')
#
# File ~/Documents/GitHub/emoatlas/emoatlas/emolib.py:495, in EmoScores.draw_plutchik(self, scores, ax, rescale, reject_range, highlight, show_intensity_levels, font, fontweight, fontsize, show_coordinates, show_ticklabels, ticklabels_angle, ticklabels_size, height_width_ratio, title, title_size)
#     405 def draw_plutchik(
#     406     self,
#     407     scores,
#    (...)
#     422     title_size=None,
#     423 ):
#     425     """
#     426     Draw the emotions or dyads Plutchik flower.
#     427     Full details at https://github.com/alfonsosemeraro/pyplutchik/blob/master/Documentation.md
#    (...)
#     492
#     493     """
# --> 495     dp.draw_plutchik(
#     496         scores,
#     497         ax=ax,
#     498         rescale=rescale,
#     499         reject_range=reject_range,
#     500         highlight=highlight,
#     501         show_intensity_levels=show_intensity_levels,
#     502         font=font,
#     503         fontweight=fontweight,
#     504         fontsize=fontsize,
#     505         show_coordinates=show_coordinates,
#     506         show_ticklabels=show_ticklabels,
#     507         ticklabels_angle=ticklabels_angle,
#     508         ticklabels_size=ticklabels_size,
#     509         height_width_ratio=height_width_ratio,
#     510         title=title,
#     511         title_size=title_size,
#     512     )
#
# File ~/Documents/GitHub/emoatlas/emoatlas/draw_plutchik.py:744, in draw_plutchik(scores, ax, rescale, reject_range, highlight, show_intensity_levels, font, fontweight, fontsize, show_coordinates, show_ticklabels, ticklabels_angle, ticklabels_size, height_width_ratio, title, title_size)
#     731     _polar_coordinates(
#     732         ax=ax,
#     733         font=font,
#    (...)
#     740         rescale=rescale,
#     741     )
#     743 # Draw inner white circle
# --> 744 _neutral_central_circle(ax)
#     746 # Emotions and dyads are mutually exclusive
#     747 if emotions:
#
# File ~/Documents/GitHub/emoatlas/emoatlas/draw_plutchik.py:209, in _neutral_central_circle(ax, r)
#     190 """
#     191 Draws central neutral circle (in grey).
#     192
#    (...)
#     205
#     206 """
#     207 c = sg.Point(0, 0).buffer(r)
#     208 ax.add_patch(
# --> 209     PolygonPatch(
#     210         c, fc="white", ec=(0.5, 0.5, 0.5, 0.3), alpha=1, zorder=15
#     211     )
#     212 )
#     214 return ax
#
# File ~/Documents/GitHub/emoatlas/emoatlas/draw_plutchik.py:68, in PolygonPatch(polygon, **kwargs)
#      64     vals[0] = Path.MOVETO
#      65     return vals
#      67 vertices = np.concatenate(
# ---> 68     [np.asarray(polygon.exterior)[:, :2]]
#      69     + [np.asarray(r)[:, :2] for r in polygon.interiors]
#      70 )
#      71 codes = np.concatenate(
#      72     [coding(polygon.exterior)] + [coding(r) for r in polygon.interiors]
#      73 )
#      75 return PathPatch(Path(vertices, codes), **kwargs)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %%
zscores = emos.zscores(bag_of_words_cat)
emos.draw_plutchik(zscores, rescale = (-10, 10), title = 'Cat')
